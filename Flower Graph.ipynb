# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#create some data to plot
x = np.linspace(0, 5, 10)
y = x**2

# %% [markdown]
# ### Colors

# %%
#google RGB hex codes for varius colors to use
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
ax.plot(x,y,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = 'g',
       markeredgecolor = 'r')
ax.plot(x,y,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
ax.plot(x,y,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
ax.plot(x,y,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
#(1 is default for most of these things, size = 3 is 3x as big as 1)

# %% [markdown]
# ### Useless Graph Art

# %%
#fa5458
# my_fig = plt.figure()
fig, axes = plt.subplots(3, 6, figsize=(40,10), dpi=300)

axes[0][0].plot(y,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][0].plot(y,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[0][0].plot(y,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[0][0].plot(y,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][0].plot(y,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[0][0].plot(y+5,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][0].plot(y+5,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[0][0].plot(y+5,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[0][0].plot(y+5,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][0].plot(y+5,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[0][0].plot(y+10,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][0].plot(y+10,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[0][0].plot(y+10,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[0][0].plot(y+10,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][0].plot(y+10,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[0][0].plot(y+15,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][0].plot(y+15,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[0][0].plot(y+15,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[0][0].plot(y+15,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][0].plot(y+15,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')

axes[0][1].plot(-y,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][1].plot(-y,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[0][1].plot(-y,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[0][1].plot(-y,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][1].plot(-y,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[0][1].plot(-y-5,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][1].plot(-y-5,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[0][1].plot(-y-5,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[0][1].plot(-y-5,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][1].plot(-y-5,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[0][1].plot(-y-10,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][1].plot(-y-10,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[0][1].plot(-y-10,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[0][1].plot(-y-10,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][1].plot(-y-10,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[0][1].plot(-y-15,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][1].plot(-y-15,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[0][1].plot(-y-15,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[0][1].plot(-y-15,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][1].plot(-y-15,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')


axes[1][0].plot(y,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][0].plot(y,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[1][0].plot(y,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[1][0].plot(y,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][0].plot(y,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[1][0].plot(y+5,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][0].plot(y+5,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[1][0].plot(y+5,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[1][0].plot(y+5,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][0].plot(y+5,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[1][0].plot(y+10,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][0].plot(y+10,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[1][0].plot(y+10,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[1][0].plot(y+10,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][0].plot(y+10,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[1][0].plot(y+15,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][0].plot(y+15,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[1][0].plot(y+15,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[1][0].plot(y+15,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][0].plot(y+15,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')

axes[1][1].plot(-y,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][1].plot(-y,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[1][1].plot(-y,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[1][1].plot(-y,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][1].plot(-y,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[1][1].plot(-y-5,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][1].plot(-y-5,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[1][1].plot(-y-5,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[1][1].plot(-y-5,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][1].plot(-y-5,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[1][1].plot(-y-10,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][1].plot(-y-10,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[1][1].plot(-y-10,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[1][1].plot(-y-10,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][1].plot(-y-10,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[1][1].plot(-y-15,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][1].plot(-y-15,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[1][1].plot(-y-15,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[1][1].plot(-y-15,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][1].plot(-y-15,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')



axes[2][1].plot(y,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'g',
       markeredgecolor = 'r')
axes[2][1].plot(y,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[2][1].plot(y,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')

axes[2][1].plot(y-y,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'g',
       markeredgecolor = 'r')
axes[2][1].plot(y-y,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[2][1].plot(y-y,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[2][1].plot(y-y+1,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'g',
       markeredgecolor = 'r')
axes[2][1].plot(y-y+1,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[2][1].plot(y-y+1,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')


axes[2][0].plot(-y,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'g',
       markeredgecolor = 'r')
axes[2][0].plot(-y,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[2][0].plot(-y,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[2][0].plot(y-y,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'g',
       markeredgecolor = 'r')
axes[2][0].plot(y-y,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[2][0].plot(y-y,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[2][0].plot(y-y-1,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'g',
       markeredgecolor = 'r')
axes[2][0].plot(y-y-1,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[2][0].plot(y-y-1,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')


axes[0][0].set_facecolor('#ffffcc')
axes[0][1].set_facecolor('#ffffcc')
axes[1][0].set_facecolor('#ffffcc')
axes[1][1].set_facecolor('#ffffcc')
axes[2][0].set_facecolor('#ccffcc')
axes[2][1].set_facecolor('#ccffcc')


axes[0][0].spines['top'].set_color('#dddddd') 
axes[0][0].spines['left'].set_color('white')
axes[0][0].tick_params(axis='x', colors='white', size=9)
axes[0][0].tick_params(axis='y', colors='white', size=9)

axes[0][1].spines['top'].set_color('#dddddd') 
axes[0][1].spines['left'].set_color('white')
axes[0][1].tick_params(axis='x', colors='white', size=9)
axes[0][1].tick_params(axis='y', colors='white', size=9)

axes[1][0].spines['top'].set_color('#dddddd') 
axes[1][0].spines['left'].set_color('white')
axes[1][0].tick_params(axis='x', colors='white', size=9)
axes[1][0].tick_params(axis='y', colors='white', size=9)

axes[1][1].spines['top'].set_color('#dddddd') 
axes[1][1].spines['left'].set_color('white')
axes[1][1].tick_params(axis='x', colors='white', size=9)
axes[1][1].tick_params(axis='y', colors='white', size=9)

axes[2][0].spines['top'].set_color('#dddddd') 
axes[2][0].spines['left'].set_color('white')
axes[2][0].tick_params(axis='x', colors='white', size=9)
axes[2][0].tick_params(axis='y', colors='white', size=9)

axes[2][1].spines['top'].set_color('#dddddd') 
axes[2][1].spines['left'].set_color('white')
axes[2][1].tick_params(axis='x', colors='white', size=9)
axes[2][1].tick_params(axis='y', colors='white', size=9)

##################################### FLOWER 2 #####################################################################
axes[0][2].plot(y,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][2].plot(y,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#fa5458',
       markeredgecolor = 'r')
axes[0][2].plot(y,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = '#faa354',
       markeredgecolor = 'r')
axes[0][2].plot(y,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][2].plot(y,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[0][2].plot(y+5,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][2].plot(y+5,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#fa5458',
       markeredgecolor = 'r')
axes[0][2].plot(y+5,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = '#faa354',
       markeredgecolor = 'r')
axes[0][2].plot(y+5,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][2].plot(y+5,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[0][2].plot(y+10,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][2].plot(y+10,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#fa5458',
       markeredgecolor = 'r')
axes[0][2].plot(y+10,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = '#faa354',
       markeredgecolor = 'r')
axes[0][2].plot(y+10,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][2].plot(y+10,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[0][2].plot(y+15,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][2].plot(y+15,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#fa5458',
       markeredgecolor = 'r')
axes[0][2].plot(y+15,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = '#faa354',
       markeredgecolor = 'r')
axes[0][2].plot(y+15,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][2].plot(y+15,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')

axes[0][3].plot(-y,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][3].plot(-y,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#fa5458',
       markeredgecolor = 'r')
axes[0][3].plot(-y,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = '#faa354',
       markeredgecolor = 'r')
axes[0][3].plot(-y,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][3].plot(-y,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[0][3].plot(-y-5,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][3].plot(-y-5,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#fa5458',
       markeredgecolor = 'r')
axes[0][3].plot(-y-5,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = '#faa354',
       markeredgecolor = 'r')
axes[0][3].plot(-y-5,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][3].plot(-y-5,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[0][3].plot(-y-10,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][3].plot(-y-10,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#fa5458',
       markeredgecolor = 'r')
axes[0][3].plot(-y-10,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = '#faa354',
       markeredgecolor = 'r')
axes[0][3].plot(-y-10,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][3].plot(-y-10,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[0][3].plot(-y-15,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][3].plot(-y-15,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#fa5458',
       markeredgecolor = 'r')
axes[0][3].plot(-y-15,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = '#faa354',
       markeredgecolor = 'r')
axes[0][3].plot(-y-15,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][3].plot(-y-15,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')


axes[1][2].plot(y,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][2].plot(y,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#fa5458',
       markeredgecolor = 'r')
axes[1][2].plot(y,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = '#faa354',
       markeredgecolor = 'r')
axes[1][2].plot(y,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][2].plot(y,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[1][2].plot(y+5,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][2].plot(y+5,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#fa5458',
       markeredgecolor = 'r')
axes[1][2].plot(y+5,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = '#faa354',
       markeredgecolor = 'r')
axes[1][2].plot(y+5,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][2].plot(y+5,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[1][2].plot(y+10,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][2].plot(y+10,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#fa5458',
       markeredgecolor = 'r')
axes[1][2].plot(y+10,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = '#faa354',
       markeredgecolor = 'r')
axes[1][2].plot(y+10,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][2].plot(y+10,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[1][2].plot(y+15,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][2].plot(y+15,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#fa5458',
       markeredgecolor = 'r')
axes[1][2].plot(y+15,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = '#faa354',
       markeredgecolor = 'r')
axes[1][2].plot(y+15,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][2].plot(y+15,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')

axes[1][3].plot(-y,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][3].plot(-y,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#fa5458',
       markeredgecolor = 'r')
axes[1][3].plot(-y,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = '#faa354',
       markeredgecolor = 'r')
axes[1][3].plot(-y,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][3].plot(-y,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[1][3].plot(-y-5,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][3].plot(-y-5,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#fa5458',
       markeredgecolor = 'r')
axes[1][3].plot(-y-5,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = '#faa354',
       markeredgecolor = 'r')
axes[1][3].plot(-y-5,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][3].plot(-y-5,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[1][3].plot(-y-10,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][3].plot(-y-10,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#fa5458',
       markeredgecolor = 'r')
axes[1][3].plot(-y-10,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = '#faa354',
       markeredgecolor = 'r')
axes[1][3].plot(-y-10,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][3].plot(-y-10,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[1][3].plot(-y-15,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][3].plot(-y-15,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#fa5458',
       markeredgecolor = 'r')
axes[1][3].plot(-y-15,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = '#faa354',
       markeredgecolor = 'r')
axes[1][3].plot(-y-15,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][3].plot(-y-15,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')



axes[2][3].plot(y,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'g',
       markeredgecolor = 'r')
axes[2][3].plot(y,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[2][3].plot(y,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')

axes[2][3].plot(y-y,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'g',
       markeredgecolor = 'r')
axes[2][3].plot(y-y,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[2][3].plot(y-y,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[2][3].plot(y-y+1,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'g',
       markeredgecolor = 'r')
axes[2][3].plot(y-y+1,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[2][3].plot(y-y+1,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')


axes[2][2].plot(-y,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'g',
       markeredgecolor = 'r')
axes[2][2].plot(-y,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[2][2].plot(-y,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[2][2].plot(y-y,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'g',
       markeredgecolor = 'r')
axes[2][2].plot(y-y,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[2][2].plot(y-y,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[2][2].plot(y-y-1,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'g',
       markeredgecolor = 'r')
axes[2][2].plot(y-y-1,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[2][2].plot(y-y-1,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')


axes[0][2].set_facecolor('#ffffcc')
axes[0][3].set_facecolor('#ffffcc')
axes[1][2].set_facecolor('#ffffcc')
axes[1][3].set_facecolor('#ffffcc')
axes[2][2].set_facecolor('#ccffcc')
axes[2][3].set_facecolor('#ccffcc')


axes[0][2].spines['top'].set_color('#dddddd') 
axes[0][2].spines['left'].set_color('white')
axes[0][2].tick_params(axis='x', colors='white', size=9)
axes[0][2].tick_params(axis='y', colors='white', size=9)

axes[0][3].spines['top'].set_color('#dddddd') 
axes[0][3].spines['left'].set_color('white')
axes[0][3].tick_params(axis='x', colors='white', size=9)
axes[0][3].tick_params(axis='y', colors='white', size=9)

axes[1][2].spines['top'].set_color('#dddddd') 
axes[1][2].spines['left'].set_color('white')
axes[1][2].tick_params(axis='x', colors='white', size=9)
axes[1][2].tick_params(axis='y', colors='white', size=9)

axes[1][3].spines['top'].set_color('#dddddd') 
axes[1][3].spines['left'].set_color('white')
axes[1][3].tick_params(axis='x', colors='white', size=9)
axes[1][3].tick_params(axis='y', colors='white', size=9)

axes[2][2].spines['top'].set_color('#dddddd') 
axes[2][2].spines['left'].set_color('white')
axes[2][2].tick_params(axis='x', colors='white', size=9)
axes[2][2].tick_params(axis='y', colors='white', size=9)

axes[2][3].spines['top'].set_color('#dddddd') 
axes[2][3].spines['left'].set_color('white')
axes[2][3].tick_params(axis='x', colors='white', size=9)
axes[2][3].tick_params(axis='y', colors='white', size=9)
###################################### FLOWER 3 ##########################################################################
axes[0][4].plot(y,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][4].plot(y,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[0][4].plot(y,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[0][4].plot(y,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][4].plot(y,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[0][4].plot(y+5,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][4].plot(y+5,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[0][4].plot(y+5,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[0][4].plot(y+5,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][4].plot(y+5,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[0][4].plot(y+10,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][4].plot(y+10,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[0][4].plot(y+10,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[0][4].plot(y+10,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][4].plot(y+10,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[0][4].plot(y+15,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][4].plot(y+15,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[0][4].plot(y+15,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[0][4].plot(y+15,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][4].plot(y+15,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')

axes[0][5].plot(-y,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][5].plot(-y,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[0][5].plot(-y,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[0][5].plot(-y,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][5].plot(-y,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[0][5].plot(-y-5,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][5].plot(-y-5,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[0][5].plot(-y-5,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[0][5].plot(-y-5,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][5].plot(-y-5,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[0][5].plot(-y-10,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][5].plot(-y-10,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[0][5].plot(-y-10,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[0][5].plot(-y-10,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][5].plot(-y-10,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[0][5].plot(-y-15,x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[0][5].plot(-y-15,x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[0][5].plot(-y-15,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[0][5].plot(-y-15,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[0][5].plot(-y-15,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')


axes[1][4].plot(y,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][4].plot(y,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[1][4].plot(y,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[1][4].plot(y,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][4].plot(y,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[1][4].plot(y+5,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][4].plot(y+5,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[1][4].plot(y+5,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[1][4].plot(y+5,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][4].plot(y+5,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[1][4].plot(y+10,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][4].plot(y+10,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[1][4].plot(y+10,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[1][4].plot(y+10,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][4].plot(y+10,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[1][4].plot(y+15,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][4].plot(y+15,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[1][4].plot(y+15,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[1][4].plot(y+15,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][4].plot(y+15,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')

axes[1][5].plot(-y,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][5].plot(-y,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[1][5].plot(-y,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[1][5].plot(-y,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][5].plot(-y,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[1][5].plot(-y-5,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][5].plot(-y-5,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[1][5].plot(-y-5,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[1][5].plot(-y-5,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][5].plot(-y-5,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[1][5].plot(-y-10,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][5].plot(-y-10,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[1][5].plot(-y-10,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[1][5].plot(-y-10,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][5].plot(-y-10,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[1][5].plot(-y-15,-x,color='r',linewidth=25, alpha =.4, ls="-" , 
        marker = "o", markersize= 100, markerfacecolor = 'b',
       markeredgecolor = 'r')
axes[1][5].plot(-y-15,-x,color='purple',linewidth=20, alpha =.5, ls="-" , 
        marker = "o", markersize= 90, markerfacecolor = '#ff3399',
       markeredgecolor = 'r')
axes[1][5].plot(-y-15,-x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'y',
       markeredgecolor = 'r')
axes[1][5].plot(-y-15,-x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[1][5].plot(-y-15,-x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')



axes[2][5].plot(y,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'g',
       markeredgecolor = 'r')
axes[2][5].plot(y,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[2][5].plot(y,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')

axes[2][5].plot(y-y,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'g',
       markeredgecolor = 'r')
axes[2][5].plot(y-y,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[2][5].plot(y-y,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[2][5].plot(y-y+1,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'g',
       markeredgecolor = 'r')
axes[2][5].plot(y-y+1,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[2][5].plot(y-y+1,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')


axes[2][4].plot(-y,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'g',
       markeredgecolor = 'r')
axes[2][4].plot(-y,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[2][4].plot(-y,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[2][4].plot(y-y,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'g',
       markeredgecolor = 'r')
axes[2][4].plot(y-y,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[2][4].plot(y-y,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')
axes[2][4].plot(y-y-1,x,color='yellow',linewidth=10, alpha =1, ls="-" , 
        marker = "o", markersize= 50, markerfacecolor = 'g',
       markeredgecolor = 'r')
axes[2][4].plot(y-y-1,x,color='g',linewidth=10, alpha =1, ls=":" , 
        marker = "o", markersize= 20, markerfacecolor = '#ffb266',
       markeredgecolor = 'r')
axes[2][4].plot(y-y-1,x,color='b',linewidth=4, alpha =1, ls=":" , 
        marker = "o", markersize= 10, markerfacecolor = '#660033',
       markeredgecolor = 'r')


axes[0][4].set_facecolor('#ffffcc')
axes[0][5].set_facecolor('#ffffcc')
axes[1][4].set_facecolor('#ffffcc')
axes[1][5].set_facecolor('#ffffcc')
axes[2][4].set_facecolor('#ccffcc')
axes[2][5].set_facecolor('#ccffcc')


axes[0][4].spines['top'].set_color('#dddddd') 
axes[0][4].spines['left'].set_color('white')
axes[0][4].tick_params(axis='x', colors='white', size=9)
axes[0][4].tick_params(axis='y', colors='white', size=9)

axes[0][5].spines['top'].set_color('#dddddd') 
axes[0][5].spines['left'].set_color('white')
axes[0][5].tick_params(axis='x', colors='white', size=9)
axes[0][5].tick_params(axis='y', colors='white', size=9)

axes[1][4].spines['top'].set_color('#dddddd') 
axes[1][4].spines['left'].set_color('white')
axes[1][4].tick_params(axis='x', colors='white', size=9)
axes[1][4].tick_params(axis='y', colors='white', size=9)

axes[1][5].spines['top'].set_color('#dddddd') 
axes[1][5].spines['left'].set_color('white')
axes[1][5].tick_params(axis='x', colors='white', size=9)
axes[1][5].tick_params(axis='y', colors='white', size=9)

axes[2][4].spines['top'].set_color('#dddddd') 
axes[2][4].spines['left'].set_color('white')
axes[2][4].tick_params(axis='x', colors='white', size=9)
axes[2][4].tick_params(axis='y', colors='white', size=9)

axes[2][5].spines['top'].set_color('#dddddd') 
axes[2][5].spines['left'].set_color('white')
axes[2][5].tick_params(axis='x', colors='white', size=9)
axes[2][5].tick_params(axis='y', colors='white', size=9)




plt.tight_layout()

# %%
fig.savefig('/Users/ashleyhooper/Documents/GitHub/flowerart.png', dpi=200)
